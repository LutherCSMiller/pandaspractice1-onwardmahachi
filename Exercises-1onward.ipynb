# %%
# %matplotlib inline
import pandas as pd 
import numpy as np

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
titles = pd.DataFrame.from_csv('data/titles.csv', index_col=None)
titles.head()
# Out:
#                               title  year
# 0                                 8  2007
# 1                            Romans  2016
# 2                       Ultra-Toxic  2005
# 3                     The Candy Man  1969
# 4  Friends & Lovers: The Ski Trip 2  2008

# %%
titles
# Out:
#                                      title  year
# 0                                        8  2007
# 1                                   Romans  2016
# 2                              Ultra-Toxic  2005
# 3                            The Candy Man  1969
# 4         Friends & Lovers: The Ski Trip 2  2008
# 5                         Ame wa shitteita  1971
# 6                    The Truth About Women  1924
# 7                               Pedro Mico  1985
# 8                              Wall Street  1987
# 9                                  Cheekha  2012
# 10                  The Return of Joe Rich  2011
# 11                                Rozyczka  2010
# 12                           Machete Kills  2013
# 13                                Holy Man  1998
# 14               Beaches, Buns and Bikinis  2010
# 15                 Cuando los hijos se van  1969
# 16                       Du mang qing yuan  1961
# 17                  Palillo Vargas Heredia  1945
# ...

# %%
cast = pd.DataFrame.from_csv('data/cast.csv', index_col=None)
cast.head()
# Out:
#                     title  year     name   type                character     n
# 0         Suuri illusioni  1985   Homo $  actor                   Guests  22.0
# 1     Battle of the Sexes  2017  $hutter  actor          Bobby Riggs Fan  10.0
# 2    Secret in Their Eyes  2015  $hutter  actor          2002 Dodger Fan   NaN
# 3              Steve Jobs  2015  $hutter  actor  1988 Opera House Patron   NaN
# 4  Straight Outta Compton  2015  $hutter  actor              Club Patron   NaN

# %% [markdown]
# ### How many movies are listed in the titles dataframe?

# %%
len(titles)
# Out:
# 229882

# %% [markdown]
# ### What are the earliest two films listed in the titles dataframe?

# %%
earliest=titles.sort_values(['year'])
earliest
# Out:
#                                                     title  year
# 120739                                         Miss Jerry  1894
# 219516                                 The Startled Lover  1898
# 144464                           Trouble in Hogan's Alley  1900
# 100467                               Family Troubles (II)  1900
# 177294                              Soldiers of the Cross  1900
# 80983   Pierrot's Problem, or How to Make a Fat Wife O...  1900
# 27779                                         The Divorce  1903
# 67301                                   La malia dell'oro  1905
# 171131                                            Valsons  1905
# 214170                         Highlights from The Mikado  1906
# 200282             Impersonation of Nelson-McGovern Fight  1906
# 113688                        The Story of the Kelly Gang  1906
# 2441                                        Lika mot lika  1906
# 83387                                            Violante  1907
# ...

# %%
earliest[earliest.year < 1900]
# Out:
#                      title  year
# 120739          Miss Jerry  1894
# 219516  The Startled Lover  1898

# %% [markdown]
# ### How many movies have the title "Hamlet"?

# %%
titles[titles.title =='Hamlet']
# Out:
#          title  year
# 3035    Hamlet  1964
# 10097   Hamlet  2014
# 27302   Hamlet  1921
# 38050   Hamlet  1954
# 62923   Hamlet  2015
# 67926   Hamlet  1996
# 78380   Hamlet  1910
# 86938   Hamlet  2000
# 133416  Hamlet  1948
# 147685  Hamlet  2009
# 154606  Hamlet  1987
# 157280  Hamlet  1990
# 158582  Hamlet  2016
# 186225  Hamlet  1911
# 192788  Hamlet  1976
# 199405  Hamlet  1973
# 223512  Hamlet  1913
# 224569  Hamlet  2011
# 229775  Hamlet  1969

# %%
len(titles[titles.title =='Hamlet'])
# Out:
# 19

# %% [markdown]
# ### How many movies are titled "North by Northwest"?

# %%
titles[titles.title =='North by Northwest']
# Out:
#                      title  year
# 139050  North by Northwest  1959

# %%
len(titles[titles.title =='North by Northwest'])
# Out:
# 1

# %% [markdown]
# ### When was the first movie titled "Hamlet" made?

# %%
titles[titles.title =='Hamlet'].sort_values('year', ascending=True)
# Out:
#          title  year
# 78380   Hamlet  1910
# 186225  Hamlet  1911
# 223512  Hamlet  1913
# 27302   Hamlet  1921
# 133416  Hamlet  1948
# 38050   Hamlet  1954
# 3035    Hamlet  1964
# 229775  Hamlet  1969
# 199405  Hamlet  1973
# 192788  Hamlet  1976
# 154606  Hamlet  1987
# 157280  Hamlet  1990
# 67926   Hamlet  1996
# 86938   Hamlet  2000
# 147685  Hamlet  2009
# 224569  Hamlet  2011
# 10097   Hamlet  2014
# 62923   Hamlet  2015
# 158582  Hamlet  2016

# %% [markdown]
# ### List all of the "Treasure Island" movies from earliest to most recent.

# %%
titles[titles.title =='Treasure Island'].sort_values('year', ascending=False)
# Out:
#                   title  year
# 64621   Treasure Island  1999
# 122800  Treasure Island  1985
# 45301   Treasure Island  1973
# 43994   Treasure Island  1972
# 136811  Treasure Island  1950
# 209569  Treasure Island  1934
# 205617  Treasure Island  1920
# 180978  Treasure Island  1918

# %% [markdown]
# ### How many movies were made in the year 1950?

# %%
titles[titles.year==1950]
# Out:
#                                    title  year
# 64                 Margherita da Cortona  1950
# 251      Batong Buhay (sa Sentral Lusan)  1950
# 277                    The Flying Saucer  1950
# 574                   Punglo at pag-ibig  1950
# 642                        Revenue Agent  1950
# 992                         Motor Patrol  1950
# 1035                      Kamal Ke Phool  1950
# 1376                      Nuestras vidas  1950
# 1427                              Dallas  1950
# 1431                    The Savage Horde  1950
# 1824               Lo sparviero del Nilo  1950
# 1986                       Once a Sinner  1950
# 2573               Her Favourite Husband  1950
# 2616      Der Schatten des Herrn Monitor  1950
# 3005                 Let's Have a Murder  1950
# 3072                La forza del destino  1950
# 3288      Old Mother Riley, Headmistress  1950
# 3465               She Shall Have Murder  1950
# 4675                     Le grand cirque  1950
# ...

# %%
len(titles[titles.year==1950])
# Out:
# 1081

# %% [markdown]
# ### How many movies were made in the year 1960?

# %%
len(titles[titles.year==1960])
# Out:
# 1488

# %% [markdown]
# ### How many movies were made from 1950 through 1959?

# %%
titles[(titles.year >= 1950) & (titles.year <= 1959)].sort_values('year', ascending=False)
# Out:
#                                                   title  year
# 98691                                           I ladri  1959
# 212631                                    Korban Fitnah  1959
# 48303                                  Nuits de Pigalle  1959
# 212677                              Hiroshima mon amour  1959
# 212712                                          Paprika  1959
# 108480                                       Eva Dragon  1959
# 150696                                 De magische ring  1959
# 150691                                     Ye hua xiang  1959
# 84438                                  Camarote de lujo  1959
# 150690                                Sotto a chi tocca  1959
# 84252                                       Liu yue xue  1959
# 84213                       To parastratima mias athoas  1959
# 23416                         Third Man on the Mountain  1959
# 84170                                  Operation Stogie  1959
# ...

# %%
len(titles[(titles.year >= 1950) & (titles.year <= 1959)].sort_values('year', ascending=False))
# Out:
# 12602

# %% [markdown]
# ### In what years has a movie titled "Batman" been released?

# %%
titles[titles.title =='Batman']
# Out:
#          title  year
# 107587  Batman  1943
# 201542  Batman  1989

# %% [markdown]
# ### How many roles were there in the movie "Inception"?

# %%
cast[cast.title =='Inception']
# Out:
#              title  year                     name     type  \
# 92736    Inception  2010     Michael (III) August    actor
# 140820   Inception  2010             Peter Basham    actor
# 174018   Inception  2010             Tom Berenger    actor
# 187216   Inception  2010                 Ken Bhan    actor
# 246269   Inception  2010           Virgile Bramly    actor
# 309903   Inception  2010            Michael Caine    actor
# 316253   Inception  2010             Earl Cameron    actor
# 355738   Inception  2010            John Ceallach    actor
# 411751   Inception  2010            Nicolas Clerc    actor
# 421844   Inception  2010           Adam (IV) Cole    actor
# 491483   Inception  2010       Jean-Michel Dagory    actor
# 561277   Inception  2010        Leonardo DiCaprio    actor
# 650311   Inception  2010            Seve Esposito    actor
# 656547   Inception  2010      Marcus (II) Everett    actor
# 672703   Inception  2010  Zachary Christopher Fay    actor
# ...

# %%
len(cast[cast.title =='Inception'])
# Out:
# 77

# %% [markdown]
# ### How many roles in the movie "Inception" are NOT ranked by an "n" value?

# %%
nulldata=cast[cast.n.isnull()]
nulldata
nulldata[nulldata.title=='Inception']
# Out:
#              title  year                     name     type  \
# 92736    Inception  2010     Michael (III) August    actor
# 187216   Inception  2010                 Ken Bhan    actor
# 355738   Inception  2010            John Ceallach    actor
# 650311   Inception  2010            Seve Esposito    actor
# 656547   Inception  2010      Marcus (II) Everett    actor
# 672703   Inception  2010  Zachary Christopher Fay    actor
# 795000   Inception  2010        Daniel Girondeaud    actor
# 957354   Inception  2010          Andrew Hoagland    actor
# 1041630  Inception  2010          Charles Jarrell    actor
# 1054427  Inception  2010            Seong-hwan Jo    actor
# 1065296  Inception  2010          Alonzo F. Jones    actor
# 1130470  Inception  2010               Mobin Khan    actor
# 1185915  Inception  2010            Shunsaku Kud?    actor
# 1231463  Inception  2010         John (IX) Lawson    actor
# 1246732  Inception  2010    Jean-Christophe Leger    actor
# ...

# %% [markdown]
# ### But how many roles in the movie "Inception" did receive an "n" value?

# %%
len(nulldata[nulldata.title=='Inception'])
# Out:
# 26

# %% [markdown]
# ### Display the cast of "North by Northwest" in their correct "n"-value order, ignoring roles that did not earn a numeric "n" value.

# %%
nvalue =cast[cast.title=='North by Northwest'].sort_values('n', ascending=True)
nvalue[nvalue.n>=1.0]
# Out:
#                       title  year                  name     type  \
# 828313   North by Northwest  1959            Cary Grant    actor
# 3311904  North by Northwest  1959       Eva Marie Saint  actress
# 1384564  North by Northwest  1959           James Mason    actor
# 2979655  North by Northwest  1959   Jessie Royce Landis  actress
# 338569   North by Northwest  1959        Leo G. Carroll    actor
# 2880266  North by Northwest  1959  Josephine Hutchinson  actress
# 1611237  North by Northwest  1959           Philip Ober    actor
# 1211365  North by Northwest  1959         Martin Landau    actor
# 2324061  North by Northwest  1959         Adam Williams    actor
# 1721393  North by Northwest  1959          Edward Platt    actor
# 632847   North by Northwest  1959     Robert Ellenstein    actor
# 2180279  North by Northwest  1959          Les Tremayne    actor
# 441299   North by Northwest  1959       Philip Coolidge    actor
# ...

# %% [markdown]
# ### Display the entire cast, in "n"-order, of the 1972 film "Sleuth".

# %%
nvalue =cast[cast.title=='Sleuth'].sort_values('n', ascending=True)
nvalue = nvalue[nvalue.year==1972]
nvalue[nvalue.n>=1.0]
# Out:
#           title  year                name     type  \
# 1620851  Sleuth  1972    Laurence Olivier    actor
# 309931   Sleuth  1972       Michael Caine    actor
# 355001   Sleuth  1972      Alec Cawthorne    actor
# 1392381  Sleuth  1972  John (II) Matthews    actor
# 2581312  Sleuth  1972  Eve (III) Channing  actress
# 1376603  Sleuth  1972        Teddy Martin    actor
#
#                           character    n
# 1620851                 Andrew Wyke  1.0
# 309931                  Milo Tindle  2.0
# 355001            Inspector Doppler  3.0
# 1392381  Detective Sergeant Tarrant  4.0
# 2581312             Marguerite Wyke  5.0
# 1376603      Police Constable Higgs  6.0

# %% [markdown]
# ### Now display the entire cast, in "n"-order, of the 2007 version of "Sleuth".

# %%
nvalue =cast[cast.title=='Sleuth'].sort_values('n', ascending=True)
nvalue = nvalue[nvalue.year==2007]
nvalue[nvalue.n>=1.0]
# Out:
#           title  year           name   type    character    n
# 309932   Sleuth  2007  Michael Caine  actor       Andrew  1.0
# 1228911  Sleuth  2007       Jude Law  actor         Milo  2.0
# 1716240  Sleuth  2007  Harold Pinter  actor  Man on T.V.  3.0

# %% [markdown]
# ### How many roles were credited in the silent 1921 version of Hamlet?

# %%
cast[(cast.title =='Hamlet') & (cast.year == 1921)]
# Out:
#           title  year                    name     type         character    n
# 7290     Hamlet  1921        Fritz Achterberg    actor       Fortinbras,  9.0
# 435705   Hamlet  1921            Paul Conradi    actor      K?nig Hamlet  2.0
# 527578   Hamlet  1921        Anton De Verdier    actor           Laertes  7.0
# 1079601  Hamlet  1921         Hans Junkermann    actor          Polonius  6.0
# 2075993  Hamlet  1921            Heinz Stieda    actor           Horatio  5.0
# 2256143  Hamlet  1921  Eduard von Winterstein    actor          Claudius  4.0
# 2525727  Hamlet  1921         Mathilde Brandt  actress  K?nigin Gertrude  3.0
# 2892731  Hamlet  1921          Lilly Jacobson  actress           Ophelia  8.0
# 3162111  Hamlet  1921            Asta Nielsen  actress            Hamlet  1.0

# %%
len(cast[(cast.title =='Hamlet') & (cast.year == 1921)])
# Out:
# 9

# %% [markdown]
# ### How many roles were credited in Branagh’s 1996 Hamlet?

# %%
len(cast[(cast.title =='Hamlet') & (cast.year == 1996)])
# Out:
# 54

# %% [markdown]
# ### How many "Hamlet" roles have been listed in all film credits through history?

# %%
len(cast[cast.title =='Hamlet'])
# Out:
# 313

# %% [markdown]
# ### How many people have played an "Ophelia"?

# %%
cast[(cast.title =='Hamlet') & (cast.character == 'Ophelia')]
# Out:
#           title  year                  name     type character     n
# 2514533  Hamlet  1990  Helena Bonham Carter  actress   Ophelia   6.0
# 2576982  Hamlet  1973         Linda Certain  actress   Ophelia   NaN
# 2578524  Hamlet  2009       Melissa Chalsma  actress   Ophelia   4.0
# 2707274  Hamlet  1913       Gertrude Elliot  actress   Ophelia  21.0
# 2721116  Hamlet  1969    Marianne Faithfull  actress   Ophelia   4.0
# 2781588  Hamlet  2011        Lara Gilchrist  actress   Ophelia   2.0
# 2859963  Hamlet  1987      Trisha Hitchcock  actress   Ophelia   NaN
# 2892731  Hamlet  1921        Lilly Jacobson  actress   Ophelia   8.0
# 3063537  Hamlet  1964           Linda Marsh  actress   Ophelia   NaN
# 3113628  Hamlet  1976          Helen Mirren  actress   Ophelia   2.0
# 3319401  Hamlet  1911         Emilie Sannom  actress   Ophelia   4.0
# 3366432  Hamlet  1954            Mala Sinha  actress   Ophelia   1.0
# 3399299  Hamlet  2000          Julia Stiles  actress   Ophelia   7.0
# ...

# %%
len(cast[(cast.title =='Hamlet') & (cast.character == 'Ophelia')])
# Out:
# 15

# %%
cast[cast.character =='The Dude']
# Out:
#                                   title  year                 name   type  \
# 257744                 The Big Lebowski  1998         Jeff Bridges  actor
# 321994               Terms & Conditions  2015          Jordan Cann  actor
# 473830                         Stranger  2000        Scott Crowell  actor
# 541986           Pizza Man vs. the Dude  2004       Chris DeMarcus  actor
# 580443                      Sweepstakes  1931          Mike Donlin  actor
# 598385                    Self Helpless  2010       Devin The Dude  actor
# 1036303  Jay and Silent Bob Strike Back  2001  Matthew (XIX) James  actor
# 1083065                   Explicit Ills  2008   Christopher Kadish  actor
# 1298870                 American Idiots  2013     Jason Loughridge  actor
# 1317350             The Winds of Autumn  1976          Steve Lyons  actor
# 1437640                         The Liq  2016       Mark Alan Meek  actor
# 1464578                  Wild Oats Lane  1926          Jerry Miley  actor
# ...

# %% [markdown]
# ### How many people have played a role called "The Dude"?

# %%
cast[cast.character == 'The Dude']
# Out:
#                                   title  year                 name   type  \
# 257744                 The Big Lebowski  1998         Jeff Bridges  actor
# 321994               Terms & Conditions  2015          Jordan Cann  actor
# 473830                         Stranger  2000        Scott Crowell  actor
# 541986           Pizza Man vs. the Dude  2004       Chris DeMarcus  actor
# 580443                      Sweepstakes  1931          Mike Donlin  actor
# 598385                    Self Helpless  2010       Devin The Dude  actor
# 1036303  Jay and Silent Bob Strike Back  2001  Matthew (XIX) James  actor
# 1083065                   Explicit Ills  2008   Christopher Kadish  actor
# 1298870                 American Idiots  2013     Jason Loughridge  actor
# 1317350             The Winds of Autumn  1976          Steve Lyons  actor
# 1437640                         The Liq  2016       Mark Alan Meek  actor
# 1464578                  Wild Oats Lane  1926          Jerry Miley  actor
# ...

# %%
len(cast[cast.character == 'The Dude'])
# Out:
# 17

# %% [markdown]
# ### How many people have played a role called "The Stranger"?

# %%
cast[cast.character == 'The Stranger']
# Out:
#                                               title  year  \
# 24398                                         Theeb  2014
# 33725                                My Time to Die  2014
# 63648                                      Get Mean  1975
# 63651                      Lo straniero di silenzio  1968
# 63653                        Un dollaro tra i denti  1967
# 63654              Un uomo, un cavallo, una pistola  1967
# 78479                   Buzzy and the Phantom Pinto  1941
# 115271               And Here No Devil Can Hurt You  2011
# 117269                                   Hungry Man  2013
# 132395                               Trading Hearts  1988
# 134284                             The Gospel of Us  2012
# 140419                                      Winning  1969
# 189583                                Urban Odyssey  2010
# 197944                               Suit of Lights  2014
# 229021                              Land o' Lizards  1916
# ...

# %%
len(cast[cast.character == 'The Stranger'])
# Out:
# 209

# %% [markdown]
# ### How many roles has Sidney Poitier played throughout his career?

# %%
cast[cast.name == 'Sidney Poitier']
# Out:
#                                 title  year            name   type  \
# 1726010               A Patch of Blue  1965  Sidney Poitier  actor
# 1726011         A Piece of the Action  1977  Sidney Poitier  actor
# 1726012           A Raisin in the Sun  1961  Sidney Poitier  actor
# 1726013               A Warm December  1973  Sidney Poitier  actor
# 1726014             All the Young Men  1960  Sidney Poitier  actor
# 1726015                Band of Angels  1957  Sidney Poitier  actor
# 1726016             Blackboard Jungle  1955  Sidney Poitier  actor
# 1726017                  Brother John  1971  Sidney Poitier  actor
# 1726018         Buck and the Preacher  1972  Sidney Poitier  actor
# 1726019      Cry, the Beloved Country  1951  Sidney Poitier  actor
# 1726020                Duel at Diablo  1966  Sidney Poitier  actor
# 1726021              Edge of the City  1957  Sidney Poitier  actor
# 1726022               For Love of Ivy  1968  Sidney Poitier  actor
# ...

# %%
len(cast[cast.name == 'Sidney Poitier'])
# Out:
# 43

# %% [markdown]
# ### How many roles has Judi Dench played?

# %%
cast[cast.name =='Judi Dench']
# Out:
#                                                      title  year        name  \
# 2664129                              84 Charing Cross Road  1987  Judi Dench
# 2664130                                  A Handful of Dust  1988  Judi Dench
# 2664131                          A Midsummer Night's Dream  1968  Judi Dench
# 2664132                                 A Room with a View  1985  Judi Dench
# 2664133                                  A Study in Terror  1965  Judi Dench
# 2664134             Angelina Ballerina: Angelina Sets Sail  2006  Judi Dench
# 2664135                                      Casino Royale  2006  Judi Dench
# 2664136                                           Chocolat  2000  Judi Dench
# 2664137                                          Dead Cert  1974  Judi Dench
# 2664138                                    Die Another Day  2002  Judi Dench
# 2664139                                             Doogal  2006  Judi Dench
# ...

# %%
len(cast[cast.name =='Judi Dench'])
# Out:
# 54

# %% [markdown]
# ### List the supporting roles (having n=2) played by Cary Grant in the 1940s, in order by year.

# %%
cast[(cast.name=='Cary Grant') & (cast.n == 2.0)]
# Out:
#                          title  year        name   type  \
# 828278          Born to Be Bad  1934  Cary Grant  actor
# 828279        Bringing Up Baby  1938  Cary Grant  actor
# 828286           Enter Madame!  1935  Cary Grant  actor
# 828293                 Holiday  1938  Cary Grant  actor
# 828297            I'm No Angel  1933  Cary Grant  actor
# 828298            In Name Only  1939  Cary Grant  actor
# 828303        Madame Butterfly  1932  Cary Grant  actor
# 828310        My Favorite Wife  1940  Cary Grant  actor
# 828320          Penny Serenade  1941  Cary Grant  actor
# 828323      She Done Him Wrong  1933  Cary Grant  actor
# 828327         Sylvia Scarlett  1935  Cary Grant  actor
# 828330         The Awful Truth  1937  Cary Grant  actor
# 828333  The Eagle and the Hawk  1933  Cary Grant  actor
# 828340   The Toast of New York  1937  Cary Grant  actor
# 828341       The Woman Accused  1933  Cary Grant  actor
# 828342     Thirty Day Princess  1934  Cary Grant  actor
# ...

# %%
cast[(cast.name=='Cary Grant') & (cast.n == 1.0)]
# Out:
#                                        title  year        name   type  \
# 828274                 An Affair to Remember  1957  Cary Grant  actor
# 828275                  Arsenic and Old Lace  1944  Cary Grant  actor
# 828276                        Big Brown Eyes  1936  Cary Grant  actor
# 828280                               Charade  1963  Cary Grant  actor
# 828281                                Crisis  1950  Cary Grant  actor
# 828283                     Destination Tokyo  1943  Cary Grant  actor
# 828285                            Dream Wife  1953  Cary Grant  actor
# 828287          Every Girl Should Be Married  1948  Cary Grant  actor
# 828288                          Father Goose  1964  Cary Grant  actor
# 828289                         Gambling Ship  1933  Cary Grant  actor
# 828291                             Gunga Din  1939  Cary Grant  actor
# 828292                       His Girl Friday  1940  Cary Grant  actor
# ...

# %% [markdown]
# ### List the leading roles that Cary Grant played in the 1940s in order by year.

# %%
cast[(cast.name=='Cary Grant') & (cast.n == 1.0) & (cast.year >=1940) & (cast.year <1950)].sort_values('year', ascending=False)
# Out:
#                                        title  year        name   type  \
# 828296                I Was a Male War Bride  1949  Cary Grant  actor
# 828287          Every Girl Should Be Married  1948  Cary Grant  actor
# 828307  Mr. Blandings Builds His Dream House  1948  Cary Grant  actor
# 828332                     The Bishop's Wife  1947  Cary Grant  actor
# 828331      The Bachelor and the Bobby-Soxer  1947  Cary Grant  actor
# 828314                             Notorious  1946  Cary Grant  actor
# 828311                         Night and Day  1946  Cary Grant  actor
# 828275                  Arsenic and Old Lace  1944  Cary Grant  actor
# 828317                      Once Upon a Time  1944  Cary Grant  actor
# 828312             None But the Lonely Heart  1944  Cary Grant  actor
# 828283                     Destination Tokyo  1943  Cary Grant  actor
# 828309                             Mr. Lucky  1943  Cary Grant  actor
# ...

# %% [markdown]
# ### How many roles were available for actors in the 1950s?

# %%
cast[(cast.year ==1950) & (cast.type =='actor')]
# Out:
#                                              title  year  \
# 256                               Palletoori Pilla  1950
# 413                                   Hallin Janne  1950
# 414                                   Hallin Janne  1950
# 1450                     Fortunes of Captain Blood  1950
# 1466                          The Baron of Arizona  1950
# 1830     Abbott and Costello in the Foreign Legion  1950
# 1984                                      Sideshow  1950
# 4969                                       Samadhi  1950
# 5960                         Alitet ukhodit v gory  1950
# 5969                              Padeniye Berlina  1950
# 6905                           El amor no es ciego  1950
# 6914                                   Lluvia roja  1950
# 6925                             Una mujer decente  1950
# 7731                            Seven Days to Noon  1950
# 8136                                Sobre las olas  1950
# ...

# %%
len(cast[(cast.year ==1950) & (cast.type =='actor')])
# Out:
# 16453

# %% [markdown]
# ### How many roles were avilable for actresses in the 1950s?

# %%
cast[(cast.year ==1950) & (cast.type =='actress')]
# Out:
#                                    title  year                  name     type  \
# 2404854           A Woman of Distinction  1950     Lucienne & Ashour  actress
# 2404856                  Chain Lightning  1950     Lucienne & Ashour  actress
# 2405630                A Life of Her Own  1950        Dorothy Abbott  actress
# 2405634               Annie Get Your Gun  1950        Dorothy Abbott  actress
# 2405637                    Copper Canyon  1950        Dorothy Abbott  actress
# 2405671                   The Petty Girl  1950        Dorothy Abbott  actress
# 2405675               Where Danger Lives  1950        Dorothy Abbott  actress
# 2407852            El amor no es negocio  1950          Lily Aclemar  actress
# 2408566                  Lockende Gefahr  1950          Addi Adametz  actress
# 2409137                          Montana  1950         Dorothy Adams  actress
# 2409146                     Paid in Full  1950         Dorothy Adams  actress
# ...

# %%
len(cast[(cast.year ==1950) & (cast.type =='actress')])
# Out:
# 5466

# %% [markdown]
# ### How many leading roles (n=1) were available from the beginning of film history through 1980?

# %%
cast[(cast.n == 1.0) & (cast.year <= 1980)]
# Out:
#                                                      title  year  \
# 267                                           En glad gutt  1932
# 272                                      En herre med bart  1942
# 1002                                 Batman Fights Dracula  1967
# 1003                                 Batman Fights Dracula  1967
# 1007                                           Mighty Rock  1969
# 1097                              Ar Daijero, Rom agar var  1975
# 1102                                     Didi mtsvane veli  1967
# 1107                                             Kvarkvare  1978
# 1115                                    Pirveli mertskhali  1975
# 1118                             Sinatle chvens panjrebshi  1969
# 1123                                       Tsimbireli papa  1974
# 1130                                      Glakhis naambobi  1961
# 1196                                         Il pap'occhio  1980
# ...

# %%
len(cast[(cast.n == 1.0) & (cast.year <= 1980)])
# Out:
# 63537

# %% [markdown]
# ### How many non-leading roles were available through from the beginning of film history through 1980?

# %%
cast[(cast.n != 1.0) & (cast.year <= 1980)]
# Out:
#                                             title  year  \
# 29                                   Los tarantos  1963
# 31                                   Los tarantos  1963
# 38       Been Down So Long It Looks Like Up to Me  1971
# 39                         I Wanna Hold Your Hand  1978
# 40                    That's the Way of the World  1975
# 51                In the Land of the Head Hunters  1914
# 54                                   Los tarantos  1963
# 55                                   Los tarantos  1963
# 62                                Fire Down Below  1957
# 63                                   De zaak M.P.  1960
# 64                             Dorp aan de rivier  1958
# 102                                   Wild Wheels  1969
# 106                                 C.B. Hustlers  1976
# 110                             Atemlos vor Liebe  1970
# 112                           Thunder in Carolina  1960
# 115                                Die Todesarena  1953
# ...

# %%
len(cast[(cast.n != 1.0) & (cast.year <= 1980)])
# Out:
# 1087299

# %% [markdown]
# ### How many roles through 1980 were minor enough that they did not warrant a numeric "n" rank?

# %%
cast[(cast.n.isnull()) & (cast.year <= 1980)]
# Out:
#                                             title  year  \
# 38       Been Down So Long It Looks Like Up to Me  1971
# 110                             Atemlos vor Liebe  1970
# 112                           Thunder in Carolina  1960
# 115                                Die Todesarena  1953
# 129                           Schatten der Manege  1931
# 265                           Alexander den Store  1917
# 271                             Den farlige leken  1942
# 276                          The President's Lady  1953
# 278                          Olsen-banden deruda'  1977
# 313                                Arbejdet adler  1914
# 314                            Lykkens Budbringer  1918
# 341                              Bigger Than Life  1956
# 342                            Mister Scoutmaster  1953
# 344                       The Kid from Left Field  1953
# 346                      A Lion Is in the Streets  1953
# 348                                 Black Tuesday  1954
# ...

# %%
len(cast[(cast.n.isnull()) & (cast.year <= 1980)])
# Out:
# 434676
